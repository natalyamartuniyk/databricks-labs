# %% [markdown]
# # Stage 1 — Azure Resources Creation (Proof of Configuration)
#
# ### 1. Azure Storage Account (ADLS Gen2)
# * **Parameters verified:** Hierarchical namespace (Enabled), Redundancy (LRS), Region (East US), Access tier (Hot).
#
#
# ![1.png](./1.png "1.png")

# %% [markdown]
# ### 2. Azure Key Vault
# * **Parameters verified:** Region (East US), Permission model (Azure RBAC), Soft-delete (Enabled).
#
# ![2.png](./2.png "2.png")

# %% [markdown]
# ### 3. Azure Databricks Workspace
# * **Parameters verified:** Pricing tier (Trial - Premium 14-days Free DBUs), Region (East US), Resource group (UA_5816_BigData).
#
# ![3.png](./3.png "3.png")
