# %%
catalog = "dbr_dev_ua5816bd"
login = "natalkamartinuk55"

schema_name = f"{login}_bronze"
table_name = "eventhub_youtube_bronze"
scope_name = f"{login}_scope"
eventhub_name = f"{login}-stream-hub"
secret_key = f"{login}-eventhub-conn"

target_bronze_table = f"{catalog}.{schema_name}.{table_name}"
eh_checkpoint_path = f"abfss://{login}@dlsua5816bd.dfs.core.windows.net/eventhub_source/stream_checkpoint_group_fix"

conn_str = dbutils.secrets.get(scope=scope_name, key=secret_key)
eh_namespace = "evhua5816bd"
eh_bootstrap_servers = f"{eh_namespace}.servicebus.windows.net:9093"
